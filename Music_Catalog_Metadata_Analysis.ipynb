# %%
df["Genre"].value_counts().head(10)
# Out:
# Genre
# Rock                      542
# Hip Hop                   436
# Driving Beat              336
# Dramatic                  234
# RBFunk                    153
# Rock / Driving Beat        35
# Latin                      28
# RBFunk / Driving Beat      28
# Hip Hop / Driving Beat     20
# Blues                      11
# Name: count, dtype: int64

# %% [markdown]
# ## Objective
# Analyze genre distribution in a licensed music catalog to understand content trends.
#
# ## Question
# Which genres appear most frequently in the catalog?
#
# ## Insight
# Rock, Hip Hop, and Driving Beat dominate the catalog, indicating strong demand for high-energy music in picture-based production.
